# %%
import pandas as pd

# %%
import numpy as np
import re
from bs4 import BeautifulSoup 
import requests

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

India = "https://www.espncricinfo.com/records/team/batting-most-runs-career/india-6/one-day-internationals-2"
Australia ="https://www.espncricinfo.com/records/team/batting-most-runs-career/australia-2/one-day-internationals-2"
Bangladesh="https://www.espncricinfo.com/records/team/batting-most-runs-career/bangladesh-25/one-day-internationals-2"
England="https://www.espncricinfo.com/records/team/batting-most-runs-career/england-1/one-day-internationals-2"
New_zealand="https://www.espncricinfo.com/records/team/batting-most-runs-career/new-zealand-5/one-day-internationals-2"
Pakistan="https://www.espncricinfo.com/records/team/batting-most-runs-career/pakistan-7/one-day-internationals-2"
South_africa="https://www.espncricinfo.com/records/team/batting-most-runs-career/south-africa-3/one-day-internationals-2"
Srilanka="https://www.espncricinfo.com/records/team/batting-most-runs-career/sri-lanka-8/one-day-internationals-2"
West_indies="https://www.espncricinfo.com/records/team/batting-most-runs-career/west-indies-4/one-day-internationals-2"
Afghanistan="https://www.espncricinfo.com/records/team/batting-most-runs-career/afghanistan-40/one-day-internationals-2" 

# headers = {
#     "User-Agent": "Mozilla/5.0 (Linux; Android 11; SAMSUNG SM-G973U) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/14.2 Chrome/87.0.4280.141 Mobile Safari/537.36"
# }

url=[India,Australia,Bangladesh,England,New_zealand,Pakistan,South_africa,Srilanka,West_indies,Afghanistan]
Country=[]
Player=[]
Span=[]
Matches=[]
Innings=[]
Not_Out=[]
Runs=[]
Highest_score=[]
Average=[]
Ball_Faced=[]
Strike_Rate=[]
Hundreds =[]
Fiftys=[]
Zeros=[]
Fours=[]
Sixes =[]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}
for x in range(len(url)):
    response = requests.get(url[x], headers=headers)
    print(response)
    soup=BeautifulSoup(response.text)
    x = soup.find_all("td",attrs={"class":"ds-min-w-max"})
    country=soup.find_all("span",attrs={"class":"ds-text-compact-xs ds-block ds-text-typo hover:ds-text-typo-primary"})

    n=0
    while n<len(x):
        Country.append(country[1].text.split()[0])
        Player.append(x[n].text)
        n+=1
        Span.append(x[n].text)
        n+=1
        Matches.append(x[n].text)
        n+=1
        Innings.append(x[n].text)
        n+=1
        Not_Out.append(x[n].text)
        n+=1
        Runs.append(x[n].text)
        n+=1
        Highest_score.append(x[n].text)
        n+=1
        Average.append(x[n].text)
        n+=1
        Ball_Faced.append(x[n].text)
        n+=1
        Strike_Rate.append(x[n].text)
        n+=1
        Hundreds.append(x[n].text)
        n+=1
        Fiftys.append(x[n].text)
        n+=1
        Zeros.append(x[n].text)
        n+=1
        Fours.append(x[n].text)
        n+=1
        Sixes.append(x[n].text)
        n+=1
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
len(Country)
# Out:
# 1406

# %%
ODI={
"Country":Country,
"Player":Player,
"Span":Span,
"Matches":Matches,
"Innings":Innings,
"Not_Out":Not_Out,
"Runs":Runs,
"Highest_score":Highest_score,
"Average":Average,
"Ball_Faced":Ball_Faced,
"Strike_Rate":Strike_Rate,
"Hundreds":Hundreds,
"Fiftys":Fiftys,
"Zeros":Zeros,
"Fours":Fours,
"Sixes":Sixes,
}

# %%
df=pd.DataFrame(ODI)

# %%
df.iloc[160]
# Out:
# Country          Australia
# Player           ML Hayden
# Span             1993-2008
# Matches                160
# Innings                154
# Not_Out                 15
# Runs                  6131
# Highest_score         181*
# Average              44.10
# Ball_Faced            7762
# Strike_Rate          78.98
# Hundreds                10
# Fiftys                  36
# Zeros                    9
# Fours                  636
# Sixes                   87
# Name: 160, dtype: object

# %%
df
# Out:
#           Country           Player       Span Matches Innings Not_Out   Runs  \
# 1           India     SR Tendulkar  1989-2012     463     452      41  18426
# 2           India          V Kohli  2008-2025     302     290      45  14181
# 3           India       SC Ganguly  1992-2007     308     297      23  11221
# 4           India        RG Sharma  2007-2025     273     265      36  11168
# 5           India         R Dravid  1996-2011     340     314      39  10768
# ...           ...              ...        ...     ...     ...     ...    ...
# 1401  Afghanistan   Najeeb Tarakai  2017-2017       1       1       -      5
# 1402  Afghanistan    Zia-ur-Rehman  2023-2023       1       1       -      5
# 1403  Afghanistan   Zakiullah Zaki  2012-2012       1       1       1      3
# 1404  Afghanistan  Abdullah Mazari  2010-2010       2       1       -      3
# 1405  Afghanistan       Ahmed Shah  2009-2009       1       1       -      2
#
# ...

# %%
df.to_csv("ODI STAT.csv")

# %%
soup.find_all("h1",attrs={"class":"ds-text-title-m ds-font-bold ds-my-4"})
# Out:
# []

# %%
response.text
# Out:
# '\n<html>\n   <body>\n      <script src="/eblN1L-yuK/zkQSn3Emn1/wzYE2ramOV/AnJVAQ/DH5-UWBy/AE0-AQ?v=a4bff242-4162-af9e-7e17-175c2352172d&t=75693476"></script>\n      <script>\n         (function() {\n             var chlgeId = \'\';\n             var scripts = document.getElementsByTagName(\'script\');\n             for (var i = 0; i < scripts.length; i++) {\n                 if (scripts[i].src && scripts[i].src.match(/t=([^&#]*)/)) {\n                     chlgeId = scripts[i].src.match(/t=([^&#]*)/)[1];\n                 }\n             }\n             var proxied = window.XMLHttpRequest.prototype.send;\n             window.XMLHttpRequest.prototype.send = function() {\n                 var pointer = this\n                 var intervalId = window.setInterval(function() {\n                     if (pointer.readyState === 4 && pointer.responseURL && pointer.responseURL.indexOf(\'t=\' + chlgeId) > -1) {\n                         location.reload(true);\n                         clearInter
# ...

# %%
df.drop(index=0,axis=0,inplace=True)
df
# Out:
#           Country           Player       Span Matches Innings Not_Out   Runs  \
# 1           India     SR Tendulkar  1989-2012     463     452      41  18426
# 2           India          V Kohli  2008-2025     302     290      45  14181
# 3           India       SC Ganguly  1992-2007     308     297      23  11221
# 4           India        RG Sharma  2007-2025     273     265      36  11168
# 5           India         R Dravid  1996-2011     340     314      39  10768
# ...           ...              ...        ...     ...     ...     ...    ...
# 1401  Afghanistan   Najeeb Tarakai  2017-2017       1       1       -      5
# 1402  Afghanistan    Zia-ur-Rehman  2023-2023       1       1       -      5
# 1403  Afghanistan   Zakiullah Zaki  2012-2012       1       1       1      3
# 1404  Afghanistan  Abdullah Mazari  2010-2010       2       1       -      3
# 1405  Afghanistan       Ahmed Shah  2009-2009       1       1       -      2
#
# ...

# %%
a=soup.find_all("span",attrs={"class":"ds-text-compact-xs ds-block ds-text-typo hover:ds-text-typo-primary"})

print(a[1].text.split()[0])
# Out:
# India

# %%
soup.text
# Out:
# 'India ODI matches batting most runs career | ESPNcricinfoLive ScoresSeriesTeamsNewsFeaturesVideosStatsENG vs INDEdition INRecordsHome2025Ask CricinfoStatsguruIPLWorld CupWPLChampions TrophyMore RecordsIndia RecordsODI Matches RecordsBatting Most Runs Career Most runs for India in ODIs Most runsPlayerSpanMatInnsNORunsHSAveBFSR1005004s6sSR Tendulkar1989-20124634524118426200*44.832136886.234996202016195V Kohli2008-2025302290451418118357.881519293.345174161325152SC Ganguly1992-2007308297231122118340.951523573.652271161104189RG Sharma2007-2025273265361116826448.761203492.803258161045344R Dravid1996-2011340314391076815339.151512771.1812821394242MS Dhoni2004-20193472948310599183*50.231216487.1397310809222M Azharuddin1985-2000334308549378153*36.921266974.027589622+77+Yuvraj Singh2000-201730127539860915036.47984687.43145218896153V Sehwag1999-20132412359799521935.377655104.441537141092131S Dhawan2010-202216716410679314344.11743691.351739584279SK Raina2005-2018226194355615116*35.31600593.50536
# ...
